# %% [markdown]
# <a href="https://colab.research.google.com/github/vivek12367/Loan-Defaulter-Prediction/blob/main/Untitled34.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, roc_curve
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
df=pd.read_csv('/content/test_task.csv')

# %%
df.sample()
# Out:
#       loanKey rep_loan_date  first_loan  dpd_5_cnt  dpd_15_cnt  dpd_30_cnt  \
# 2594   181017    2015-09-26  2015-06-21        NaN         NaN         NaN
#
#      first_overdue_date  close_loans_cnt federal_district_nm  TraderKey  ...  \
# 2594                NaN              1.0            region_3         12  ...
#
#       payment_type_2  payment_type_3  payment_type_4  payment_type_5  \
# 2594               3               0               0               0
#
#       past_billings_cnt     score_1  score_2   age  gender  bad_flag
# 2594                3.0  579.372921      NaN  23.0    True         0
#
# [1 rows x 22 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4157 entries, 0 to 4156
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   loanKey              4157 non-null   int64
#  1   rep_loan_date        4157 non-null   object
#  2   first_loan           4157 non-null   object
#  3   dpd_5_cnt            675 non-null    float64
#  4   dpd_15_cnt           675 non-null    float64
#  5   dpd_30_cnt           675 non-null    float64
#  6   first_overdue_date   675 non-null    object
#  7   close_loans_cnt      4142 non-null   float64
#  8   federal_district_nm  4146 non-null   object
#  9   TraderKey            4157 non-null   int64
#  10  payment_type_0       4157 non-null   int64
#  11  payment_type_1       4157 non-null   int64
#  12  payment_type_2       4157 non-null   int64
#  13  payment_type_3       4157 non-null   int64
#  14  payment_type_4       4157 non-null   int64
# ...

# %%
df.isnull().sum()
# Out:
# loanKey                   0
# rep_loan_date             0
# first_loan                0
# dpd_5_cnt              3482
# dpd_15_cnt             3482
# dpd_30_cnt             3482
# first_overdue_date     3482
# close_loans_cnt          15
# federal_district_nm      11
# TraderKey                 0
# payment_type_0            0
# payment_type_1            0
# payment_type_2            0
# payment_type_3            0
# payment_type_4            0
# payment_type_5            0
# past_billings_cnt       248
# score_1                 650
# score_2                3918
# age                       0
# gender                    0
# bad_flag                  0
# dtype: int64

# %%
df['rep_loan_date'] = pd.to_datetime(df['rep_loan_date'])
df['first_loan'] = pd.to_datetime(df['first_loan'])
df['first_overdue_date'] = pd.to_datetime(df['first_overdue_date'], errors='coerce')

# %%
# Drop columns with too many missing values or less relevance
df.drop(columns=['score_2', 'first_overdue_date', 'dpd_5_cnt', 'dpd_15_cnt', 'dpd_30_cnt'], inplace=True)

# %%
for col in ['score_1', 'past_billings_cnt', 'close_loans_cnt']:
    df[col] = df[col].fillna(df[col].median())

# %%
df['gender'] = df['gender'].astype(int)

# %%
df['federal_district_nm'] = df['federal_district_nm'].astype('category').cat.codes

# %%
df['loan_relationship_days'] = (df['rep_loan_date'] - df['first_loan']).dt.days

# %%
payment_type_cols = [f'payment_type_{i}' for i in range(6)]
df['total_payment_type_freq'] = df[payment_type_cols].sum(axis=1)

# %%
df.drop(columns=['loanKey', 'TraderKey', 'rep_loan_date', 'first_loan'], inplace=True)

# %%
# Correlation matrix
plt.figure(figsize=(12, 10))
sns.heatmap(df.corr(), annot=True, fmt=".2f", cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %%
# Numeric distributions
numeric_cols = ['score_1', 'past_billings_cnt', 'close_loans_cnt', 'age', 'loan_relationship_days']
df[numeric_cols].hist(bins=30, figsize=(14, 8))
plt.suptitle("Feature Distributions")
plt.tight_layout()
plt.show()

# %%
# Default rate by gender
sns.barplot(x='gender', y='bad_flag', data=df)
plt.xticks([0, 1], ['Female', 'Male'])
plt.title("Default Rate by Gender")
plt.show()

# %%
# Default rate by region
plt.figure(figsize=(12, 4))
sns.barplot(x='federal_district_nm', y='bad_flag', data=df)
plt.title("Default Rate by Region Code")
plt.show()

# %%
X = df.drop(columns=['bad_flag'])
y = df['bad_flag']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.2, random_state=42)

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE(random_state=42)
X_train_sm, y_train_sm = smote.fit_resample(X_train, y_train)

# %%
# Standardize for logistic regression
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# ✅ Step 5: Train Logistic Regression
model = LogisticRegression(class_weight='balanced', random_state=42)
model.fit(X_train_sm, y_train_sm)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(class_weight='balanced', random_state=42)

# %%
y_pred = model.predict(X_test_scaled)
y_prob = model.predict_proba(X_test_scaled)[:, 1]
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
print("=== Classification Report ===")
print(classification_report(y_test, y_pred))
# Out:
# === Classification Report ===
#               precision    recall  f1-score   support
#
#            0       0.90      0.22      0.36       749
#            1       0.10      0.78      0.18        83
#
#     accuracy                           0.28       832
#    macro avg       0.50      0.50      0.27       832
# weighted avg       0.82      0.28      0.34       832

# %%
print("=== Confusion Matrix ===")
print(confusion_matrix(y_test, y_pred))
# Out:
# === Confusion Matrix ===
# [[166 583]
#  [ 18  65]]

# %%
print("=== ROC AUC ===")
print("AUC Score:", roc_auc_score(y_test, y_prob))
# Out:
# === ROC AUC ===
# AUC Score: 0.47005646082326635

# %%
# ✅ Step 7: ROC Curve
fpr, tpr, _ = roc_curve(y_test, y_prob)
plt.figure(figsize=(8, 5))
plt.plot(fpr, tpr, label=f"AUC = {roc_auc_score(y_test, y_prob):.2f}")
plt.plot([0, 1], [0, 1], 'k--')
plt.title("ROC Curve")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import precision_recall_curve

# %%
# ✅ Step 8: Precision-Recall Curve
precision, recall, thresholds = precision_recall_curve(y_test, y_prob)
plt.figure(figsize=(8, 5))
plt.plot(thresholds, precision[:-1], label="Precision")
plt.plot(thresholds, recall[:-1], label="Recall")
plt.title("Precision and Recall vs Threshold")
plt.xlabel("Threshold")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
threshold_df = pd.DataFrame({'prob': y_prob, 'true': y_test.values})
thresholds_range = np.arange(0.1, 1.01, 0.01)
default_rates = []

for threshold in thresholds_range:
    approved = threshold_df[threshold_df['prob'] >= threshold]
    default_rate = approved['true'].mean() if len(approved) > 0 else np.nan
    default_rates.append(default_rate)

plt.figure(figsize=(10, 6))
plt.plot(thresholds_range, default_rates, marker='o')
plt.title("Expected Default Rate vs Approval Threshold")
plt.xlabel("Approval Threshold")
plt.ylabel("Observed Default Rate")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# ✅ Step 1: Import XGBoost
from xgboost import XGBClassifier

# ✅ Step 2: Apply SMOTE to training data
from imblearn.over_sampling import SMOTE
smote = SMOTE(random_state=42)
X_train_sm, y_train_sm = smote.fit_resample(X_train, y_train)

# ✅ Step 3: Train XGBoost model
xgb_model = XGBClassifier(use_label_encoder=False, eval_metric='logloss', random_state=42)
xgb_model.fit(X_train_sm, y_train_sm)

# ✅ Step 4: Predict on test set
y_pred_xgb = xgb_model.predict(X_test)
y_prob_xgb = xgb_model.predict_proba(X_test)[:, 1]
# Out:
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [01:32:05] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)

# %%
# ✅ Step 5: Evaluation
print("=== XGBoost Classification Report ===")
print(classification_report(y_test, y_pred_xgb))
# Out:
# === XGBoost Classification Report ===
#               precision    recall  f1-score   support
#
#            0       0.92      0.91      0.92       749
#            1       0.24      0.25      0.25        83
#
#     accuracy                           0.85       832
#    macro avg       0.58      0.58      0.58       832
# weighted avg       0.85      0.85      0.85       832

# %%
print("=== Confusion Matrix ===")
print(confusion_matrix(y_test, y_pred_xgb))
# Out:
# === Confusion Matrix ===
# [[684  65]
#  [ 62  21]]

# %%
print("=== ROC AUC Score ===")
print(roc_auc_score(y_test, y_prob_xgb))
# Out:
# === ROC AUC Score ===
# 0.6763234513487864

# %%
fpr, tpr, _ = roc_curve(y_test, y_prob_xgb)
plt.figure(figsize=(8, 5))
plt.plot(fpr, tpr, label=f"XGBoost (AUC = {roc_auc_score(y_test, y_prob_xgb):.2f})")
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("XGBoost ROC Curve")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Feature Importance Plot
importance_df = pd.DataFrame({
    'Feature': X.columns,
    'Importance': xgb_model.feature_importances_
}).sort_values(by='Importance', ascending=False)

plt.figure(figsize=(10, 6))
sns.barplot(data=importance_df, x='Importance', y='Feature', palette='viridis')
plt.title("XGBoost Feature Importances")
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-44-ea080fa57413>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=importance_df, x='Importance', y='Feature', palette='viridis')

# %%
import shap
explainer = shap.Explainer(xgb_model)
shap_values = explainer(X_test)
shap.summary_plot(shap_values, X_test)

# %%
# Summary metrics from your classification report
xgb_summary = {
    'Precision (Default)': 0.24,
    'Recall (Default)': 0.25,
    'F1 Score (Default)': 0.25,
    'Accuracy': 0.85,
    'ROC AUC': 0.69  # Replace with your actual ROC AUC if available
}

# Create bar plot
plt.figure(figsize=(8, 5))
sns.barplot(x=list(xgb_summary.keys()), y=list(xgb_summary.values()), palette='Blues_d')
plt.ylim(0, 1)
plt.title("📊 XGBoost Performance Summary (with SMOTE)", fontsize=14)
plt.ylabel("Score")
plt.xticks(rotation=30)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-51-b986ccd34945>:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=list(xgb_summary.keys()), y=list(xgb_summary.values()), palette='Blues_d')
# <ipython-input-51-b986ccd34945>:17: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
